# %% [markdown]
# ## Diss matrix

# %%
# %load_ext autoreload
# %autoreload 2


from pathlib import Path
import sys
import matplotlib.pyplot as plt


# Path to data 
dataFolderPath = Path(r"D:\Stage\ACCAL\data\dataTest2","temp",)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dissMatrix = np.load(Path(dataFolderPath,"distMatrix.npy"))

#Nb =  np.load(Path(dataFolderPath,"Nb.npy"))
#P = np.load(Path(dataFolderPath,"P.npy"))

# %%
plt.imshow(dissMatrix)
plt.colorbar()

# %%
n,bins,patches = plt.hist(dissMatrix[np.nonzero(dissMatrix)],100,log=True)
