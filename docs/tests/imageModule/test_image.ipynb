# %% [markdown]
# # Example / test how to use image module

# %%
import os
import sys

# %load_ext autoreload
# %autoreload 2

# TO CHANGE
# absolute path to ACCAL/ACCAL folder 
accalPath = r"D:\Stage\ACCAL\ACCAL"
sys.path.append(accalPath)


# absolute path to data
dataPath = r"D:\Stage\ACCAL\data\dataTest1"
dataList = os.listdir(dataPath)
img1Path = os.path.join(dataPath,dataList[0])


import Image.processing
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Crop to coin function

# %%
fig,axes = plt.subplots(1,2,figsize=(14,7))
ax1,ax2 = axes

ax1.set_title("Original")
ax1.imshow(plt.imread(img1Path))

ax2.set_title("Cropped")
ax2.imshow(Image.processing.cropToCoin(img1Path))
plt.show()
